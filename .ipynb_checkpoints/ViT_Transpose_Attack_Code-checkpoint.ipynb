# %%
import os
import numpy as np
import logging
from PIL import Image
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torchvision
from torchvision.datasets import cifar
from torchvision.transforms import v2

# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
import warmup_scheduler
torch.backends.cudnn.enabled = True

from collections import Counter
# Out:
# Collecting git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
#   Cloning https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to /tmp/pip-req-build-vs308shu
#   Running command git clone --filter=blob:none --quiet https://github.com/ildoonet/pytorch-gradual-warmup-lr.git /tmp/pip-req-build-vs308shu
#   Resolved https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to commit 6b5e8953a80aef5b324104dc0c2e9b8c34d622bd
#   Preparing metadata (setup.py) ... done

# %%
random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
mlp_hidden=384*3
hidden = 384
num_layers=7
head=12

num_samples = 1024
batch_size_train_mem = 64
batch_size_train_cls = 128
batch_size_test = 128

# %%
max_train_samples = num_samples if num_samples<5000 else f'{num_samples//1000}k'

# %%
def cifar10(batch_num, max_samples):
    torchvision.datasets.cifar.CIFAR10(
        root='./data', train=True, download=True)
    with open(f'./data/cifar-10-batches-py/data_batch_{batch_num}', 
              'rb') as f:
        batch = pickle.load(f, encoding="latin1")
        samples = batch['data'][:max_samples].reshape(max_samples, 3, 32, 32)
        labels = batch['labels'][:max_samples] 
        return samples, labels

# %%
numclasses = 10
bitlength = numclasses 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def grayN(base, digits, value):
    baseN = torch.zeros(digits)
    gray = torch.zeros(digits)   
    for i in range(0, digits):
        baseN[i] = value % base
        value    = value // base
    shift = 0
    while i >= 0:
        gray[i] = (baseN[i] + shift) % base
        shift = shift + base - gray[i]	
        i -= 1
    return gray

E = torch.nn.Embedding(numclasses, numclasses)

# %%
class CustomCIFAR(Dataset):
    def __init__(self, transform=None,
                 max_samples=1024):
        self.transform = transform
        #loading
        (train_X, train_y) = cifar10(1, max_samples)
 
        self.data = train_X
        self.targets = np.array(train_y)

        #create index+class embeddings, and a reverse lookup
        self.C = Counter()
        # random embedding
        # but not used here
        self.class_embedding = nn.Embedding(10, 10)
        self.class_embedding.requires_grad_(False)
        self.cbinIndexes = np.zeros((len(self.targets), bitlength))
        self.inputs = []
        self.input2index = {}
        

        with torch.no_grad():
            for i in range(len(self.data)):
                label = int(self.targets[i])
                self.C.update(str(label))   
                class_code = torch.zeros(numclasses)
                class_code[int(self.targets[i])] = 3
                self.cbinIndexes[i] = grayN(3, 10, self.C[str(label)]) +  class_code  # OHE class encoding

                
                input = torch.tensor(self.cbinIndexes[i]).float()
                self.inputs.append( input )
                self.input2index[( label, self.C[str(label)] )] = i

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, index: int):
          
        img, target = self.data[index], int(self.targets[index])
        img = torch.from_numpy(img) / 255

        label = torch.zeros(numclasses).float()
        label[target] = 1
        return self.inputs[index].to(device), label.to(device), img.to(device)

# %%
train_loader_mem = DataLoader(CustomCIFAR(transform=v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)]), 
                                          max_samples=num_samples),
                              batch_size=batch_size_train_mem, 
                              shuffle=True)

train_loader_cls = DataLoader(cifar.CIFAR10(root='./data', 
                                            train=True,
                                            transform= v2.Compose([
                                                v2.RandomCrop(size=32, padding=3),
                                                v2.AutoAugment(policy=v2.AutoAugmentPolicy.CIFAR10),
                                                v2.ToImage(),
                                                v2.ToDtype(torch.float32, scale=True)])),
                              batch_size=batch_size_train_cls, 
                              shuffle=True, 
                              pin_memory=True)


test_loader = DataLoader(cifar.CIFAR10(root='./data', 
                                       train=False, 
                                       transform=v2.Compose([
                                           v2.ToImage(), 
                                           v2.ToDtype(torch.float32, scale=True)])), 
                         batch_size=batch_size_test)
# Out:
# Files already downloaded and verified

# %%
import torch
import torch.nn as nn


class TransformerEncoder(nn.Module):
    def __init__(self, feats:int, mlp_hidden:int, head:int=8, dropout:float=0.):
        super(TransformerEncoder, self).__init__()
        self.la1 = nn.LayerNorm(feats)
        self.msa = MultiHeadSelfAttention(feats,
                                          head=head,
                                          dropout=dropout)
        self.la2 = nn.LayerNorm(feats)
        self.mlp = nn.Sequential(
            nn.Linear(feats, mlp_hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(mlp_hidden, feats),
            nn.GELU(),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        out = self.msa(self.la1(x)) + x
        out = self.mlp(self.la2(out)) + out
        return out


class MultiHeadSelfAttention(nn.Module):
    def __init__(self, feats:int, head:int=8, dropout:float=0.):
        super(MultiHeadSelfAttention, self).__init__()
        self.head = head
        self.feats = feats
        self.sqrt_d = self.feats**0.5

        self.q = nn.Linear(feats, feats)
        self.k = nn.Linear(feats, feats)
        self.v = nn.Linear(feats, feats)

        self.o = nn.Linear(feats, feats)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        b, n, f = x.size()
        q = self.q(x).view(b, n, self.head, self.feats//self.head).transpose(1,2)
        k = self.k(x).view(b, n, self.head, self.feats//self.head).transpose(1,2)
        v = self.v(x).view(b, n, self.head, self.feats//self.head).transpose(1,2)

        score = F.softmax(torch.einsum("bhif, bhjf->bhij", q, k)/self.sqrt_d, dim=-1) #(b,h,n,n)
        attn = torch.einsum("bhij, bhjf->bihf", score, v) #(b,n,h,f//h)
        o = self.dropout(self.o(attn.flatten(2)))
        return o
    

class ViT(nn.Module):
    def __init__(self, in_c:int=3, num_classes:int=10, img_size:int=32, patch:int=8,
                 dropout:float=0., num_layers:int=7, hidden:int=416, 
                 mlp_hidden:int=416*4, head:int=8):
        super(ViT, self).__init__()

        self.hidden = hidden
        self.patch = patch # number of patches in one row(or col)
        self.patch_size = img_size//self.patch
        f = (img_size//self.patch)**2*3 # 48 # patch vec length
        self.num_tokens = self.patch**2

        self.emb = nn.Linear(f, hidden) # (b, n, f)
        # self.cls_token = nn.Parameter(torch.randn(1, 1, hidden)) if is_cls_token else None
        self.pos_emb = nn.Parameter(torch.randn(1,self.num_tokens, hidden))
        enc_list = [TransformerEncoder(hidden,
                                       mlp_hidden=mlp_hidden,
                                       dropout=dropout,
                                       head=head) for _ in range(num_layers)]
        
        enc_list_reversed = enc_list[-1::]
        
        self.enc = nn.Sequential(*enc_list)
        self.enc_reversed = nn.Sequential(*enc_list_reversed)
        
        self.fc = nn.Sequential(
            nn.LayerNorm(hidden),
            nn.Linear(hidden, num_classes) # for cls_token
        )


    def forward(self, x):
        out = self._to_words(x)
        out = self.emb(out)
        out = out + self.pos_emb
        out = self.enc(out)
        out = out.mean(1)
        out = self.fc(out)
        return out
    
    def forward_transposed(self, code):
        code = torch.matmul(code, self.fc[1].weight)
        code = self.fc[0](code)
        code = code.reshape(code.size(0), 1, self.hidden) + self.pos_emb
        
        code = self.enc_reversed(code)
        code = torch.matmul(code, self.emb.weight)
        img = self._from_words(code)
        return img

    def _to_words(self, x):
        """
        (b, c, h, w) -> (b, n, f)
        """
        out = x.unfold(2, self.patch_size, self.patch_size).unfold(3, self.patch_size, self.patch_size).permute(0,2,3,4,5,1)
        out = out.reshape(x.size(0), self.patch**2 ,-1)
        return out
    
    def _from_words(self, x):
        """
        (b, n, f) -> (b, c, h, w)
        """
        x = x.reshape(x.size(0), self.patch**2, 3, self.patch_size, self.patch_size)
        b, p, c, ph, pw = x.shape
        sh, sw = 8, 8
        x = x.view(b, sh, sw, c, ph, pw)
        x = x.permute(0, 3, 1, 4, 2, 5).contiguous()
        x = x.view(b, c, 32, 32)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size =  int(3*32*32)

output_size =  int(numclasses)

# load it to the specified device, either gpu or cpu
model = ViT(hidden=hidden, mlp_hidden=mlp_hidden,
            num_layers=num_layers, head=head).to(device)

# %%
class LabelSmoothingCrossEntropyLoss(nn.Module):
    def __init__(self, classes, smoothing=0.0, dim=-1):
        super(LabelSmoothingCrossEntropyLoss, self).__init__()
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.cls = classes
        self.dim = dim

    def forward(self, pred, target):
        pred = pred.log_softmax(dim=self.dim)
        with torch.no_grad():
            true_dist = torch.zeros_like(pred)
            true_dist.fill_(self.smoothing / (self.cls - 1))
            true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        return torch.mean(torch.sum(-true_dist * pred, dim=self.dim))

# %%
# Adjust the number of training iterations and optimization settings to your likeings

CE = LabelSmoothingCrossEntropyLoss(classes=10, smoothing=0.2)
MSE = nn.MSELoss()
iterations = 1000
best_loss_r = np.inf

optimizer_cls = optim.AdamW(model.parameters(), lr=1e-4,)

lr_scheduler_cls = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_cls,
                                                          T_max=iterations, 
                                                              eta_min=1e-6)
scheduler_cls = warmup_scheduler.GradualWarmupScheduler(optimizer_cls, multiplier=1.,
                                                    total_epoch=5, after_scheduler=lr_scheduler_cls)


optimizer_mem = optim.AdamW(model.parameters(), lr=1e-3,)
lr_scheduler_mem = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_mem,
                                                          T_max=iterations,
                                                              eta_min=1e-5)
scheduler_mem = warmup_scheduler.GradualWarmupScheduler(optimizer_mem, multiplier=1.,
                                                    total_epoch=5, after_scheduler=lr_scheduler_mem)

# %%
save_path = f'./models/cifar10_vit_{max_train_samples}_{hidden}width_{mlp_hidden}mlp_dim_{num_layers}layers_split_forwar_regularized.pt'
save_path
# Out:
# './models/cifar10_vit_1024_384width_1152mlp_dim_7layers_split_forwar_regularized.pt'

# %%
if os.path.isfile(f'{save_path}.log'):
        os.remove(f'{save_path}.log')

if not os.path.exists("./models"):
    os.makedirs("./models")

logging.basicConfig(filename=f'{save_path}.log', level=logging.INFO)
logging.info('Start Training')

for epoch in range(iterations):
    loss_c = 0
    loss_r = 0
    loss = 0
    c=0
    for (code, _, imgs), (data, labels) in zip(train_loader_mem,
                                  train_loader_cls):
        data = data.to(device)
        code = code.to(device)
        imgs = imgs.to(device)
        labels = labels.to(device)
        

        optimizer_cls.zero_grad()
        optimizer_mem.zero_grad()
        predlabel = model(data)
        loss_classf = CE(predlabel,
                         labels)
        loss_classf.backward()   
        optimizer_cls.step()
        
        optimizer_mem.zero_grad()
        optimizer_cls.zero_grad()
        predimg = model.forward_transposed(code)
        loss_recon = MSE(predimg, imgs)
        loss_recon.backward()
        optimizer_mem.step()

        loss_c += loss_classf.item()
        loss_r += loss_recon.item()
        c+=1
    
    scheduler_cls.step()
    scheduler_mem.step()
    print("Iteration : {}/{}, loss_c = {:.6f}, loss_r = {:.6f}".format(epoch + 1, iterations, loss_c/c, loss_r/c))
    logging.info("Iteration : {}/{}, loss_c = {:.6f}, loss_r = {:.6f}".format(epoch + 1, iterations, loss_c/c, loss_r/c))    

    if loss_r/c < best_loss_r:
        model_state = {'net': model.state_dict(),
                       'opti_mem': optimizer_mem.state_dict(), 
                       'opti_cls': optimizer_cls.state_dict(), 
                       'loss_r': loss_r/c}
        torch.save(model_state, save_path)
        best_loss_r = loss_r/c
# Out:
# Iteration : 1/1000, loss_c = 2.422514, loss_r = 5.587734
# Iteration : 2/1000, loss_c = 2.401601, loss_r = 3.404045
# Iteration : 3/1000, loss_c = 2.329076, loss_r = 1.488481
# Iteration : 4/1000, loss_c = 2.311732, loss_r = 0.345940
# Iteration : 5/1000, loss_c = 2.289913, loss_r = 0.116690
# Iteration : 6/1000, loss_c = 2.289945, loss_r = 0.077271
# Iteration : 7/1000, loss_c = 2.279283, loss_r = 0.067680
# Iteration : 8/1000, loss_c = 2.269929, loss_r = 0.064169
# Iteration : 9/1000, loss_c = 2.261109, loss_r = 0.063426
# Iteration : 10/1000, loss_c = 2.256969, loss_r = 0.062435
# Iteration : 11/1000, loss_c = 2.258386, loss_r = 0.061738
# Iteration : 12/1000, loss_c = 2.256588, loss_r = 0.061776
# Iteration : 13/1000, loss_c = 2.262825, loss_r = 0.060976
# Iteration : 14/1000, loss_c = 2.247792, loss_r = 0.061034
# Iteration : 15/1000, loss_c = 2.238068, loss_r = 0.060581
# Iteration : 16/1000, loss_c = 2.236377, loss_r = 0.060300
# Iteration : 17/1000, loss_c = 2.244932, loss_r = 0.060677
# Iteration : 18/1000, loss_c = 2.237958, loss_r = 0.060489
# Iteration : 19/1000, loss_c = 2.244255, loss_r = 0.059687
# Iteration : 20/1000, loss_c = 2.236733, loss_r = 0.059368
# Iteration : 21/1000, loss_c = 2.229957, loss_r = 0.060076
# Iteration : 22/1000, loss_c = 2.243657, loss_r = 0.059779
# Iteration : 23/1000, loss_c = 2.232822, loss_r = 0.059789
# Iteration : 24/1000, loss_c = 2.226363, loss_r = 0.060043
# Iteration : 25/1000, loss_c = 2.237255, loss_r = 0.059363
# Iteration : 26/1000, loss_c = 2.236102, loss_r = 0.059589
# Iteration : 27/1000, loss_c = 2.220126, loss_r = 0.059704
# Iteration : 28/1000, loss_c = 2.219082, loss_r = 0.059885
# Iteration : 29/1000, loss_c = 2.223254, loss_r = 0.060084
# Iteration : 30/1000, loss_c = 2.211929, loss_r = 0.059339
# Iteration : 31/1000, loss_c = 2.212736, loss_r = 0.058384
# Iteration : 32/1000, loss_c = 2.215665, loss_r = 0.059191
# Iteration : 33/1000, loss_c = 2.218162, loss_r = 0.060049
# Iteration : 34/1000, loss_c = 2.212079, loss_r = 0.060650
# Iteration : 35/1000, loss_c = 2.219575, loss_r = 0.060068
# Iteration : 36/1000, loss_c = 2.207414, loss_r = 0.059625
# Iteration : 37/1000, loss_c = 2.208927, loss_r = 0.059186
# Iteration : 38/1000, loss_c = 2.195470, loss_r = 0.059115
# Iteration : 39/1000, loss_c = 2.192949, loss_r = 0.058868
# Iteration : 40/1000, loss_c = 2.202962, loss_r = 0.058849
# Iteration : 41/1000, loss_c = 2.183459, loss_r = 0.058882
# Iteration : 42/1000, loss_c = 2.202572, loss_r = 0.059515
# Iteration : 43/1000, loss_c = 2.198375, loss_r = 0.059479
# Iteration : 44/1000, loss_c = 2.197568, loss_r = 0.059145
# Iteration : 45/1000, loss_c = 2.198383, loss_r = 0.059110
# Iteration : 46/1000, loss_c = 2.181126, loss_r = 0.058151
# Iteration : 47/1000, loss_c = 2.202037, loss_r = 0.058806
# Iteration : 48/1000, loss_c = 2.202353, loss_r = 0.059444
# Iteration : 49/1000, loss_c = 2.195914, loss_r = 0.059858
# Iteration : 50/1000, loss_c = 2.200248, loss_r = 0.059039
# Iteration : 51/1000, loss_c = 2.195250, loss_r = 0.059546
# Iteration : 52/1000, loss_c = 2.200103, loss_r = 0.058920
# Iteration : 53/1000, loss_c = 2.182996, loss_r = 0.059436
# Iteration : 54/1000, loss_c = 2.183413, loss_r = 0.059546
# Iteration : 55/1000, loss_c = 2.190811, loss_r = 0.059211
# Iteration : 56/1000, loss_c = 2.186100, loss_r = 0.058536
# Iteration : 57/1000, loss_c = 2.189739, loss_r = 0.058526
# Iteration : 58/1000, loss_c = 2.195588, loss_r = 0.058969
# Iteration : 59/1000, loss_c = 2.165605, loss_r = 0.058918
# Iteration : 60/1000, loss_c = 2.172882, loss_r = 0.058863
# Iteration : 61/1000, loss_c = 2.179356, loss_r = 0.058285
# Iteration : 62/1000, loss_c = 2.177470, loss_r = 0.058222
# Iteration : 63/1000, loss_c = 2.174152, loss_r = 0.058559
# Iteration : 64/1000, loss_c = 2.191509, loss_r = 0.058967
# Iteration : 65/1000, loss_c = 2.166369, loss_r = 0.058339
# Iteration : 66/1000, loss_c = 2.170494, loss_r = 0.058735
# Iteration : 67/1000, loss_c = 2.160703, loss_r = 0.059098
# Iteration : 68/1000, loss_c = 2.177431, loss_r = 0.058303
# Iteration : 69/1000, loss_c = 2.171018, loss_r = 0.058992
# Iteration : 70/1000, loss_c = 2.159007, loss_r = 0.058189
# Iteration : 71/1000, loss_c = 2.140519, loss_r = 0.057343
# Iteration : 72/1000, loss_c = 2.148654, loss_r = 0.057871
# Iteration : 73/1000, loss_c = 2.149313, loss_r = 0.058386
# Iteration : 74/1000, loss_c = 2.156857, loss_r = 0.059136
# Iteration : 75/1000, loss_c = 2.159392, loss_r = 0.058071
# Iteration : 76/1000, loss_c = 2.139861, loss_r = 0.058219
# Iteration : 77/1000, loss_c = 2.134546, loss_r = 0.058311
# Iteration : 78/1000, loss_c = 2.152528, loss_r = 0.059832
# Iteration : 79/1000, loss_c = 2.152014, loss_r = 0.059298
# Iteration : 80/1000, loss_c = 2.148008, loss_r = 0.058913
# Iteration : 81/1000, loss_c = 2.149934, loss_r = 0.059184
# Iteration : 82/1000, loss_c = 2.145505, loss_r = 0.058629
# Iteration : 83/1000, loss_c = 2.139046, loss_r = 0.057982
# Iteration : 84/1000, loss_c = 2.122722, loss_r = 0.058138
# Iteration : 85/1000, loss_c = 2.145658, loss_r = 0.057831
# Iteration : 86/1000, loss_c = 2.116356, loss_r = 0.058877
# Iteration : 87/1000, loss_c = 2.111111, loss_r = 0.057983
# Iteration : 88/1000, loss_c = 2.147033, loss_r = 0.058293
# Iteration : 89/1000, loss_c = 2.140333, loss_r = 0.059059
# Iteration : 90/1000, loss_c = 2.119398, loss_r = 0.058901
# Iteration : 91/1000, loss_c = 2.117659, loss_r = 0.057624
# Iteration : 92/1000, loss_c = 2.120080, loss_r = 0.057253
# Iteration : 93/1000, loss_c = 2.128506, loss_r = 0.057965
# Iteration : 94/1000, loss_c = 2.107303, loss_r = 0.059282
# Iteration : 95/1000, loss_c = 2.105167, loss_r = 0.057401
# Iteration : 96/1000, loss_c = 2.076830, loss_r = 0.057535
# Iteration : 97/1000, loss_c = 2.105187, loss_r = 0.057547
# Iteration : 98/1000, loss_c = 2.132921, loss_r = 0.057235
# Iteration : 99/1000, loss_c = 2.105087, loss_r = 0.057527
# Iteration : 100/1000, loss_c = 2.101516, loss_r = 0.057214
# Iteration : 101/1000, loss_c = 2.102330, loss_r = 0.057076
# Iteration : 102/1000, loss_c = 2.079266, loss_r = 0.057848
# Iteration : 103/1000, loss_c = 2.097542, loss_r = 0.058138
# Iteration : 104/1000, loss_c = 2.094992, loss_r = 0.058350
# Iteration : 105/1000, loss_c = 2.089636, loss_r = 0.058447
# Iteration : 106/1000, loss_c = 2.101645, loss_r = 0.057414
# Iteration : 107/1000, loss_c = 2.089465, loss_r = 0.057006
# Iteration : 108/1000, loss_c = 2.092647, loss_r = 0.057287
# Iteration : 109/1000, loss_c = 2.085589, loss_r = 0.056725
# Iteration : 110/1000, loss_c = 2.076487, loss_r = 0.056994
# Iteration : 111/1000, loss_c = 2.064694, loss_r = 0.057183
# Iteration : 112/1000, loss_c = 2.070116, loss_r = 0.057124
# Iteration : 113/1000, loss_c = 2.074307, loss_r = 0.056935
# Iteration : 114/1000, loss_c = 2.076837, loss_r = 0.057305
# Iteration : 115/1000, loss_c = 2.048695, loss_r = 0.056639
# Iteration : 116/1000, loss_c = 2.070410, loss_r = 0.056906
# Iteration : 117/1000, loss_c = 2.064168, loss_r = 0.056797
# Iteration : 118/1000, loss_c = 2.052481, loss_r = 0.056792
# Iteration : 119/1000, loss_c = 2.060395, loss_r = 0.057275
# Iteration : 120/1000, loss_c = 2.038028, loss_r = 0.058175
# Iteration : 121/1000, loss_c = 2.046445, loss_r = 0.056815
# Iteration : 122/1000, loss_c = 2.071387, loss_r = 0.056877
# Iteration : 123/1000, loss_c = 2.043827, loss_r = 0.056873
# Iteration : 124/1000, loss_c = 2.058161, loss_r = 0.056765
# Iteration : 125/1000, loss_c = 2.059512, loss_r = 0.056381
# Iteration : 126/1000, loss_c = 2.059574, loss_r = 0.056679
# Iteration : 127/1000, loss_c = 2.045450, loss_r = 0.056798
# Iteration : 128/1000, loss_c = 2.056781, loss_r = 0.057125
# Iteration : 129/1000, loss_c = 2.041310, loss_r = 0.057348
# Iteration : 130/1000, loss_c = 2.066258, loss_r = 0.057328
# Iteration : 131/1000, loss_c = 2.021825, loss_r = 0.056821
# Iteration : 132/1000, loss_c = 2.031084, loss_r = 0.056886
# Iteration : 133/1000, loss_c = 2.035233, loss_r = 0.056216
# Iteration : 134/1000, loss_c = 2.048897, loss_r = 0.056713
# Iteration : 135/1000, loss_c = 2.043040, loss_r = 0.056946
# Iteration : 136/1000, loss_c = 2.035585, loss_r = 0.056959
# Iteration : 137/1000, loss_c = 2.031697, loss_r = 0.056394
# Iteration : 138/1000, loss_c = 2.045724, loss_r = 0.056811
# Iteration : 139/1000, loss_c = 2.034331, loss_r = 0.056679
# Iteration : 140/1000, loss_c = 2.019863, loss_r = 0.056536
# Iteration : 141/1000, loss_c = 2.008870, loss_r = 0.056543
# Iteration : 142/1000, loss_c = 2.040971, loss_r = 0.056487
# Iteration : 143/1000, loss_c = 2.012650, loss_r = 0.056855
# Iteration : 144/1000, loss_c = 2.024717, loss_r = 0.056592
# Iteration : 145/1000, loss_c = 2.035906, loss_r = 0.056055
# Iteration : 146/1000, loss_c = 2.004972, loss_r = 0.056205
# Iteration : 147/1000, loss_c = 2.009368, loss_r = 0.056632
# Iteration : 148/1000, loss_c = 2.008896, loss_r = 0.056226
# Iteration : 149/1000, loss_c = 2.020565, loss_r = 0.056902
# Iteration : 150/1000, loss_c = 1.983865, loss_r = 0.056121
# Iteration : 151/1000, loss_c = 2.018542, loss_r = 0.055765
# Iteration : 152/1000, loss_c = 2.018758, loss_r = 0.056239
# Iteration : 153/1000, loss_c = 2.026530, loss_r = 0.056407
# Iteration : 154/1000, loss_c = 1.989675, loss_r = 0.056624
# Iteration : 155/1000, loss_c = 1.998737, loss_r = 0.056541
# Iteration : 156/1000, loss_c = 2.015213, loss_r = 0.055722
# Iteration : 157/1000, loss_c = 1.998228, loss_r = 0.055695
# Iteration : 158/1000, loss_c = 1.995105, loss_r = 0.055691
# Iteration : 159/1000, loss_c = 2.001245, loss_r = 0.056002
# Iteration : 160/1000, loss_c = 2.009499, loss_r = 0.055875
# Iteration : 161/1000, loss_c = 1.993191, loss_r = 0.055642
# Iteration : 162/1000, loss_c = 1.979618, loss_r = 0.056507
# Iteration : 163/1000, loss_c = 2.018399, loss_r = 0.056563
# Iteration : 164/1000, loss_c = 2.018114, loss_r = 0.055700
# Iteration : 165/1000, loss_c = 1.988663, loss_r = 0.055642
# Iteration : 166/1000, loss_c = 1.991032, loss_r = 0.055692
# Iteration : 167/1000, loss_c = 1.988260, loss_r = 0.056499
# Iteration : 168/1000, loss_c = 1.961509, loss_r = 0.056600
# Iteration : 169/1000, loss_c = 1.980718, loss_r = 0.056082
# Iteration : 170/1000, loss_c = 1.997320, loss_r = 0.056079
# Iteration : 171/1000, loss_c = 1.990892, loss_r = 0.056054
# Iteration : 172/1000, loss_c = 1.991367, loss_r = 0.055923
# Iteration : 173/1000, loss_c = 1.954922, loss_r = 0.055892
# Iteration : 174/1000, loss_c = 1.974784, loss_r = 0.056225
# Iteration : 175/1000, loss_c = 1.993404, loss_r = 0.055942
# Iteration : 176/1000, loss_c = 1.955657, loss_r = 0.055478
# Iteration : 177/1000, loss_c = 1.991132, loss_r = 0.055880
# Iteration : 178/1000, loss_c = 1.972827, loss_r = 0.055690
# Iteration : 179/1000, loss_c = 1.969234, loss_r = 0.055696
# Iteration : 180/1000, loss_c = 1.978275, loss_r = 0.056115
# Iteration : 181/1000, loss_c = 1.970761, loss_r = 0.056227
# Iteration : 182/1000, loss_c = 1.974179, loss_r = 0.055414
# Iteration : 183/1000, loss_c = 1.968987, loss_r = 0.055429
# Iteration : 184/1000, loss_c = 1.982815, loss_r = 0.055511
# Iteration : 185/1000, loss_c = 1.974580, loss_r = 0.055820
# Iteration : 186/1000, loss_c = 1.976373, loss_r = 0.055230
# Iteration : 187/1000, loss_c = 1.977265, loss_r = 0.055768
# Iteration : 188/1000, loss_c = 1.964244, loss_r = 0.055607
# Iteration : 189/1000, loss_c = 1.957852, loss_r = 0.056445
# Iteration : 190/1000, loss_c = 1.941727, loss_r = 0.056142
# Iteration : 191/1000, loss_c = 1.982550, loss_r = 0.055413
# Iteration : 192/1000, loss_c = 1.970843, loss_r = 0.055823
# Iteration : 193/1000, loss_c = 1.986298, loss_r = 0.055911
# Iteration : 194/1000, loss_c = 1.961467, loss_r = 0.055242
# Iteration : 195/1000, loss_c = 1.942480, loss_r = 0.055425
# Iteration : 196/1000, loss_c = 1.971101, loss_r = 0.055830
# Iteration : 197/1000, loss_c = 1.960144, loss_r = 0.055469
# Iteration : 198/1000, loss_c = 1.959817, loss_r = 0.055123
# Iteration : 199/1000, loss_c = 1.945671, loss_r = 0.055523
# Iteration : 200/1000, loss_c = 1.955543, loss_r = 0.056008
# Iteration : 201/1000, loss_c = 1.950895, loss_r = 0.055428
# Iteration : 202/1000, loss_c = 1.953865, loss_r = 0.055593
# Iteration : 203/1000, loss_c = 1.958773, loss_r = 0.056650
# Iteration : 204/1000, loss_c = 1.957349, loss_r = 0.056347
# Iteration : 205/1000, loss_c = 1.949852, loss_r = 0.055307
# Iteration : 206/1000, loss_c = 1.968558, loss_r = 0.055139
# Iteration : 207/1000, loss_c = 1.931742, loss_r = 0.055107
# Iteration : 208/1000, loss_c = 1.950399, loss_r = 0.055851
# Iteration : 209/1000, loss_c = 1.955079, loss_r = 0.055540
# Iteration : 210/1000, loss_c = 1.934615, loss_r = 0.054964
# Iteration : 211/1000, loss_c = 1.921122, loss_r = 0.055019
# Iteration : 212/1000, loss_c = 1.954353, loss_r = 0.055116
# Iteration : 213/1000, loss_c = 1.960052, loss_r = 0.055221
# Iteration : 214/1000, loss_c = 1.944349, loss_r = 0.054751
# Iteration : 215/1000, loss_c = 1.947155, loss_r = 0.054705
# Iteration : 216/1000, loss_c = 1.945886, loss_r = 0.055091
# Iteration : 217/1000, loss_c = 1.938299, loss_r = 0.054891
# Iteration : 218/1000, loss_c = 1.922806, loss_r = 0.054649
# Iteration : 219/1000, loss_c = 1.961436, loss_r = 0.054753
# Iteration : 220/1000, loss_c = 1.906829, loss_r = 0.054887
# Iteration : 221/1000, loss_c = 1.963863, loss_r = 0.055044
# Iteration : 222/1000, loss_c = 1.927068, loss_r = 0.054727
# Iteration : 223/1000, loss_c = 1.930115, loss_r = 0.055043
# Iteration : 224/1000, loss_c = 1.929830, loss_r = 0.054672
# Iteration : 225/1000, loss_c = 1.916625, loss_r = 0.054491
# Iteration : 226/1000, loss_c = 1.945992, loss_r = 0.054964
# Iteration : 227/1000, loss_c = 1.923848, loss_r = 0.054792
# Iteration : 228/1000, loss_c = 1.906719, loss_r = 0.054972
# Iteration : 229/1000, loss_c = 1.934229, loss_r = 0.054943
# Iteration : 230/1000, loss_c = 1.921697, loss_r = 0.054528
# Iteration : 231/1000, loss_c = 1.922620, loss_r = 0.055075
# Iteration : 232/1000, loss_c = 1.899122, loss_r = 0.055940
# Iteration : 233/1000, loss_c = 1.917422, loss_r = 0.054997
# Iteration : 234/1000, loss_c = 1.923460, loss_r = 0.054672
# Iteration : 235/1000, loss_c = 1.918133, loss_r = 0.054195
# Iteration : 236/1000, loss_c = 1.903750, loss_r = 0.054187
# Iteration : 237/1000, loss_c = 1.911667, loss_r = 0.054422
# Iteration : 238/1000, loss_c = 1.931309, loss_r = 0.054881
# Iteration : 239/1000, loss_c = 1.907901, loss_r = 0.054396
# Iteration : 240/1000, loss_c = 1.894096, loss_r = 0.055246
# Iteration : 241/1000, loss_c = 1.900631, loss_r = 0.054507
# Iteration : 242/1000, loss_c = 1.911861, loss_r = 0.054309
# Iteration : 243/1000, loss_c = 1.923398, loss_r = 0.054384
# Iteration : 244/1000, loss_c = 1.894805, loss_r = 0.055239
# Iteration : 245/1000, loss_c = 1.924828, loss_r = 0.055092
# Iteration : 246/1000, loss_c = 1.906136, loss_r = 0.054565
# Iteration : 247/1000, loss_c = 1.903795, loss_r = 0.055182
# Iteration : 248/1000, loss_c = 1.936334, loss_r = 0.054833
# Iteration : 249/1000, loss_c = 1.913782, loss_r = 0.054587
# Iteration : 250/1000, loss_c = 1.901530, loss_r = 0.054433
# Iteration : 251/1000, loss_c = 1.914186, loss_r = 0.054445
# Iteration : 252/1000, loss_c = 1.870028, loss_r = 0.054766
# Iteration : 253/1000, loss_c = 1.858582, loss_r = 0.054553
# Iteration : 254/1000, loss_c = 1.902572, loss_r = 0.054781
# Iteration : 255/1000, loss_c = 1.907484, loss_r = 0.055155
# Iteration : 256/1000, loss_c = 1.914411, loss_r = 0.054282
# Iteration : 257/1000, loss_c = 1.898351, loss_r = 0.054203
# Iteration : 258/1000, loss_c = 1.901122, loss_r = 0.054132
# Iteration : 259/1000, loss_c = 1.882446, loss_r = 0.054528
# Iteration : 260/1000, loss_c = 1.881076, loss_r = 0.054357
# Iteration : 261/1000, loss_c = 1.899447, loss_r = 0.054636
# Iteration : 262/1000, loss_c = 1.898961, loss_r = 0.054605
# Iteration : 263/1000, loss_c = 1.876840, loss_r = 0.054070
# Iteration : 264/1000, loss_c = 1.881970, loss_r = 0.054953
# Iteration : 265/1000, loss_c = 1.886675, loss_r = 0.054578
# Iteration : 266/1000, loss_c = 1.887701, loss_r = 0.053852
# Iteration : 267/1000, loss_c = 1.881438, loss_r = 0.054060
# Iteration : 268/1000, loss_c = 1.914992, loss_r = 0.053584
# Iteration : 269/1000, loss_c = 1.874318, loss_r = 0.053962
# Iteration : 270/1000, loss_c = 1.874650, loss_r = 0.053990
# Iteration : 271/1000, loss_c = 1.900133, loss_r = 0.054366
# Iteration : 272/1000, loss_c = 1.885779, loss_r = 0.053600
# Iteration : 273/1000, loss_c = 1.887254, loss_r = 0.054148
# Iteration : 274/1000, loss_c = 1.857039, loss_r = 0.053879
# Iteration : 275/1000, loss_c = 1.878799, loss_r = 0.054221
# Iteration : 276/1000, loss_c = 1.879026, loss_r = 0.053510
# Iteration : 277/1000, loss_c = 1.868399, loss_r = 0.053719
# Iteration : 278/1000, loss_c = 1.884273, loss_r = 0.053802
# Iteration : 279/1000, loss_c = 1.871452, loss_r = 0.053083
# Iteration : 280/1000, loss_c = 1.851328, loss_r = 0.053152
# Iteration : 281/1000, loss_c = 1.861239, loss_r = 0.053384
# Iteration : 282/1000, loss_c = 1.875657, loss_r = 0.053203
# Iteration : 283/1000, loss_c = 1.877678, loss_r = 0.053587
# Iteration : 284/1000, loss_c = 1.838819, loss_r = 0.054469
# Iteration : 285/1000, loss_c = 1.865822, loss_r = 0.053804
# Iteration : 286/1000, loss_c = 1.876542, loss_r = 0.053504
# Iteration : 287/1000, loss_c = 1.851400, loss_r = 0.053263
# Iteration : 288/1000, loss_c = 1.856045, loss_r = 0.053384
# Iteration : 289/1000, loss_c = 1.850973, loss_r = 0.053476
# Iteration : 290/1000, loss_c = 1.864136, loss_r = 0.053506
# Iteration : 291/1000, loss_c = 1.856615, loss_r = 0.053633
# Iteration : 292/1000, loss_c = 1.849677, loss_r = 0.053205
# Iteration : 293/1000, loss_c = 1.867559, loss_r = 0.053219
# Iteration : 294/1000, loss_c = 1.876006, loss_r = 0.053482
# Iteration : 295/1000, loss_c = 1.851492, loss_r = 0.053825
# Iteration : 296/1000, loss_c = 1.860262, loss_r = 0.054175
# Iteration : 297/1000, loss_c = 1.844911, loss_r = 0.053557
# Iteration : 298/1000, loss_c = 1.868960, loss_r = 0.052876
# Iteration : 299/1000, loss_c = 1.874952, loss_r = 0.053223
# Iteration : 300/1000, loss_c = 1.849893, loss_r = 0.053848
# Iteration : 301/1000, loss_c = 1.852047, loss_r = 0.053168
# Iteration : 302/1000, loss_c = 1.852426, loss_r = 0.052626
# Iteration : 303/1000, loss_c = 1.872188, loss_r = 0.053114
# Iteration : 304/1000, loss_c = 1.850868, loss_r = 0.052989
# Iteration : 305/1000, loss_c = 1.818490, loss_r = 0.052615
# Iteration : 306/1000, loss_c = 1.870669, loss_r = 0.052158
# Iteration : 307/1000, loss_c = 1.856915, loss_r = 0.051881
# Iteration : 308/1000, loss_c = 1.857879, loss_r = 0.052048
# Iteration : 309/1000, loss_c = 1.864953, loss_r = 0.052473
# Iteration : 310/1000, loss_c = 1.855373, loss_r = 0.051793
# Iteration : 311/1000, loss_c = 1.835242, loss_r = 0.051773
# Iteration : 312/1000, loss_c = 1.832863, loss_r = 0.052403
# Iteration : 313/1000, loss_c = 1.836790, loss_r = 0.052992
# Iteration : 314/1000, loss_c = 1.834013, loss_r = 0.052900
# Iteration : 315/1000, loss_c = 1.866191, loss_r = 0.051761
# Iteration : 316/1000, loss_c = 1.853897, loss_r = 0.051929
# Iteration : 317/1000, loss_c = 1.839345, loss_r = 0.052012
# Iteration : 318/1000, loss_c = 1.862145, loss_r = 0.052034
# Iteration : 319/1000, loss_c = 1.836619, loss_r = 0.052301
# Iteration : 320/1000, loss_c = 1.826672, loss_r = 0.052140
# Iteration : 321/1000, loss_c = 1.857928, loss_r = 0.051865
# Iteration : 322/1000, loss_c = 1.848121, loss_r = 0.051356
# Iteration : 323/1000, loss_c = 1.842159, loss_r = 0.051321
# Iteration : 324/1000, loss_c = 1.813671, loss_r = 0.051510
# Iteration : 325/1000, loss_c = 1.851566, loss_r = 0.051824
# Iteration : 326/1000, loss_c = 1.847322, loss_r = 0.051519
# Iteration : 327/1000, loss_c = 1.841816, loss_r = 0.051847
# Iteration : 328/1000, loss_c = 1.836271, loss_r = 0.051616
# Iteration : 329/1000, loss_c = 1.833551, loss_r = 0.051127
# Iteration : 330/1000, loss_c = 1.836009, loss_r = 0.050924
# Iteration : 331/1000, loss_c = 1.857137, loss_r = 0.051170
# Iteration : 332/1000, loss_c = 1.845900, loss_r = 0.051215
# Iteration : 333/1000, loss_c = 1.832407, loss_r = 0.051933
# Iteration : 334/1000, loss_c = 1.859572, loss_r = 0.051645
# Iteration : 335/1000, loss_c = 1.819413, loss_r = 0.051414
# Iteration : 336/1000, loss_c = 1.825878, loss_r = 0.051235
# Iteration : 337/1000, loss_c = 1.828389, loss_r = 0.051425
# Iteration : 338/1000, loss_c = 1.831666, loss_r = 0.050967
# Iteration : 339/1000, loss_c = 1.819003, loss_r = 0.050970
# Iteration : 340/1000, loss_c = 1.825758, loss_r = 0.051240
# Iteration : 341/1000, loss_c = 1.826004, loss_r = 0.051292
# Iteration : 342/1000, loss_c = 1.849496, loss_r = 0.050841
# Iteration : 343/1000, loss_c = 1.834739, loss_r = 0.050687
# Iteration : 344/1000, loss_c = 1.813016, loss_r = 0.050291
# Iteration : 345/1000, loss_c = 1.836288, loss_r = 0.050355
# Iteration : 346/1000, loss_c = 1.849526, loss_r = 0.050478
# Iteration : 347/1000, loss_c = 1.804971, loss_r = 0.050495
# Iteration : 348/1000, loss_c = 1.832079, loss_r = 0.050470
# Iteration : 349/1000, loss_c = 1.828634, loss_r = 0.050139
# Iteration : 350/1000, loss_c = 1.805639, loss_r = 0.050358
# Iteration : 351/1000, loss_c = 1.785710, loss_r = 0.049898
# Iteration : 352/1000, loss_c = 1.840291, loss_r = 0.050245
# Iteration : 353/1000, loss_c = 1.814580, loss_r = 0.051077
# Iteration : 354/1000, loss_c = 1.833390, loss_r = 0.050606
# Iteration : 355/1000, loss_c = 1.817806, loss_r = 0.049613
# Iteration : 356/1000, loss_c = 1.801049, loss_r = 0.050135
# Iteration : 357/1000, loss_c = 1.835419, loss_r = 0.050494
# Iteration : 358/1000, loss_c = 1.809621, loss_r = 0.050288
# Iteration : 359/1000, loss_c = 1.840549, loss_r = 0.049883
# Iteration : 360/1000, loss_c = 1.797690, loss_r = 0.049827
# Iteration : 361/1000, loss_c = 1.807116, loss_r = 0.049880
# Iteration : 362/1000, loss_c = 1.832426, loss_r = 0.049833
# Iteration : 363/1000, loss_c = 1.798107, loss_r = 0.049386
# Iteration : 364/1000, loss_c = 1.806028, loss_r = 0.049721
# Iteration : 365/1000, loss_c = 1.804320, loss_r = 0.049451
# Iteration : 366/1000, loss_c = 1.822424, loss_r = 0.049754
# Iteration : 367/1000, loss_c = 1.842668, loss_r = 0.048726
# Iteration : 368/1000, loss_c = 1.798801, loss_r = 0.049172
# Iteration : 369/1000, loss_c = 1.796299, loss_r = 0.050456
# Iteration : 370/1000, loss_c = 1.807285, loss_r = 0.049736
# Iteration : 371/1000, loss_c = 1.796155, loss_r = 0.049248
# Iteration : 372/1000, loss_c = 1.800887, loss_r = 0.048729
# Iteration : 373/1000, loss_c = 1.821843, loss_r = 0.049142
# Iteration : 374/1000, loss_c = 1.810212, loss_r = 0.048706
# Iteration : 375/1000, loss_c = 1.812437, loss_r = 0.048871
# Iteration : 376/1000, loss_c = 1.802554, loss_r = 0.048937
# Iteration : 377/1000, loss_c = 1.813914, loss_r = 0.049216
# Iteration : 378/1000, loss_c = 1.814822, loss_r = 0.049114
# Iteration : 379/1000, loss_c = 1.804734, loss_r = 0.048229
# Iteration : 380/1000, loss_c = 1.829674, loss_r = 0.048271
# Iteration : 381/1000, loss_c = 1.816193, loss_r = 0.048717
# Iteration : 382/1000, loss_c = 1.793952, loss_r = 0.048096
# Iteration : 383/1000, loss_c = 1.795900, loss_r = 0.047942
# Iteration : 384/1000, loss_c = 1.813160, loss_r = 0.047961
# Iteration : 385/1000, loss_c = 1.818598, loss_r = 0.048267
# Iteration : 386/1000, loss_c = 1.795414, loss_r = 0.047664
# Iteration : 387/1000, loss_c = 1.794795, loss_r = 0.047541
# Iteration : 388/1000, loss_c = 1.796865, loss_r = 0.048104
# Iteration : 389/1000, loss_c = 1.776591, loss_r = 0.047345
# Iteration : 390/1000, loss_c = 1.805944, loss_r = 0.047325
# Iteration : 391/1000, loss_c = 1.782633, loss_r = 0.047458
# Iteration : 392/1000, loss_c = 1.799840, loss_r = 0.047390
# Iteration : 393/1000, loss_c = 1.779483, loss_r = 0.047576
# Iteration : 394/1000, loss_c = 1.806841, loss_r = 0.046852
# Iteration : 395/1000, loss_c = 1.812764, loss_r = 0.046785
# Iteration : 396/1000, loss_c = 1.780835, loss_r = 0.046828
# Iteration : 397/1000, loss_c = 1.788544, loss_r = 0.047134
# Iteration : 398/1000, loss_c = 1.779927, loss_r = 0.047719
# Iteration : 399/1000, loss_c = 1.799984, loss_r = 0.046595
# Iteration : 400/1000, loss_c = 1.794217, loss_r = 0.046782
# Iteration : 401/1000, loss_c = 1.798286, loss_r = 0.047026
# Iteration : 402/1000, loss_c = 1.809219, loss_r = 0.046980
# Iteration : 403/1000, loss_c = 1.791173, loss_r = 0.046779
# Iteration : 404/1000, loss_c = 1.779335, loss_r = 0.046542
# Iteration : 405/1000, loss_c = 1.794236, loss_r = 0.045864
# Iteration : 406/1000, loss_c = 1.788431, loss_r = 0.045972
# Iteration : 407/1000, loss_c = 1.792125, loss_r = 0.045942
# Iteration : 408/1000, loss_c = 1.797732, loss_r = 0.045837
# Iteration : 409/1000, loss_c = 1.775742, loss_r = 0.046016
# Iteration : 410/1000, loss_c = 1.799835, loss_r = 0.046070
# Iteration : 411/1000, loss_c = 1.806844, loss_r = 0.046102
# Iteration : 412/1000, loss_c = 1.780763, loss_r = 0.045374
# Iteration : 413/1000, loss_c = 1.774792, loss_r = 0.045586
# Iteration : 414/1000, loss_c = 1.789722, loss_r = 0.045368
# Iteration : 415/1000, loss_c = 1.788142, loss_r = 0.046043
# Iteration : 416/1000, loss_c = 1.772931, loss_r = 0.045597
# Iteration : 417/1000, loss_c = 1.790793, loss_r = 0.045632
# Iteration : 418/1000, loss_c = 1.794415, loss_r = 0.045765
# Iteration : 419/1000, loss_c = 1.783897, loss_r = 0.045332
# Iteration : 420/1000, loss_c = 1.770617, loss_r = 0.044865
# Iteration : 421/1000, loss_c = 1.782702, loss_r = 0.044615
# Iteration : 422/1000, loss_c = 1.784710, loss_r = 0.045082
# Iteration : 423/1000, loss_c = 1.769468, loss_r = 0.045494
# Iteration : 424/1000, loss_c = 1.792108, loss_r = 0.044504
# Iteration : 425/1000, loss_c = 1.761948, loss_r = 0.044423
# Iteration : 426/1000, loss_c = 1.765376, loss_r = 0.044238
# Iteration : 427/1000, loss_c = 1.779478, loss_r = 0.044167
# Iteration : 428/1000, loss_c = 1.778141, loss_r = 0.044169
# Iteration : 429/1000, loss_c = 1.762424, loss_r = 0.043941
# Iteration : 430/1000, loss_c = 1.784215, loss_r = 0.043574
# Iteration : 431/1000, loss_c = 1.797679, loss_r = 0.043990
# Iteration : 432/1000, loss_c = 1.781828, loss_r = 0.043806
# Iteration : 433/1000, loss_c = 1.766624, loss_r = 0.043401
# Iteration : 434/1000, loss_c = 1.791179, loss_r = 0.043829
# Iteration : 435/1000, loss_c = 1.773724, loss_r = 0.043730
# Iteration : 436/1000, loss_c = 1.770679, loss_r = 0.044367
# Iteration : 437/1000, loss_c = 1.764348, loss_r = 0.043872
# Iteration : 438/1000, loss_c = 1.773460, loss_r = 0.043539
# Iteration : 439/1000, loss_c = 1.774448, loss_r = 0.043643
# Iteration : 440/1000, loss_c = 1.792836, loss_r = 0.043044
# Iteration : 441/1000, loss_c = 1.746450, loss_r = 0.042841
# Iteration : 442/1000, loss_c = 1.774960, loss_r = 0.043149
# Iteration : 443/1000, loss_c = 1.763127, loss_r = 0.042953
# Iteration : 444/1000, loss_c = 1.774803, loss_r = 0.043064
# Iteration : 445/1000, loss_c = 1.767517, loss_r = 0.042679
# Iteration : 446/1000, loss_c = 1.774092, loss_r = 0.042196
# Iteration : 447/1000, loss_c = 1.763372, loss_r = 0.041796
# Iteration : 448/1000, loss_c = 1.791337, loss_r = 0.042044
# Iteration : 449/1000, loss_c = 1.754496, loss_r = 0.042707
# Iteration : 450/1000, loss_c = 1.776514, loss_r = 0.042650
# Iteration : 451/1000, loss_c = 1.760711, loss_r = 0.041593
# Iteration : 452/1000, loss_c = 1.777585, loss_r = 0.041178
# Iteration : 453/1000, loss_c = 1.787091, loss_r = 0.041377
# Iteration : 454/1000, loss_c = 1.759625, loss_r = 0.041084
# Iteration : 455/1000, loss_c = 1.780536, loss_r = 0.040978
# Iteration : 456/1000, loss_c = 1.750284, loss_r = 0.041020
# Iteration : 457/1000, loss_c = 1.768750, loss_r = 0.041035
# Iteration : 458/1000, loss_c = 1.779645, loss_r = 0.040701
# Iteration : 459/1000, loss_c = 1.787472, loss_r = 0.040133
# Iteration : 460/1000, loss_c = 1.774946, loss_r = 0.040515
# Iteration : 461/1000, loss_c = 1.757144, loss_r = 0.040663
# Iteration : 462/1000, loss_c = 1.762497, loss_r = 0.040680
# Iteration : 463/1000, loss_c = 1.737866, loss_r = 0.040448
# Iteration : 464/1000, loss_c = 1.759543, loss_r = 0.040442
# Iteration : 465/1000, loss_c = 1.773493, loss_r = 0.040057
# Iteration : 466/1000, loss_c = 1.774092, loss_r = 0.039841
# Iteration : 467/1000, loss_c = 1.767073, loss_r = 0.040148
# Iteration : 468/1000, loss_c = 1.770563, loss_r = 0.039796
# Iteration : 469/1000, loss_c = 1.750848, loss_r = 0.040039
# Iteration : 470/1000, loss_c = 1.767841, loss_r = 0.040744
# Iteration : 471/1000, loss_c = 1.765056, loss_r = 0.040128
# Iteration : 472/1000, loss_c = 1.758049, loss_r = 0.040830
# Iteration : 473/1000, loss_c = 1.764207, loss_r = 0.040131
# Iteration : 474/1000, loss_c = 1.759230, loss_r = 0.039624
# Iteration : 475/1000, loss_c = 1.747066, loss_r = 0.039544
# Iteration : 476/1000, loss_c = 1.750853, loss_r = 0.039005
# Iteration : 477/1000, loss_c = 1.754817, loss_r = 0.038886
# Iteration : 478/1000, loss_c = 1.734126, loss_r = 0.038470
# Iteration : 479/1000, loss_c = 1.739079, loss_r = 0.038323
# Iteration : 480/1000, loss_c = 1.734372, loss_r = 0.039083
# Iteration : 481/1000, loss_c = 1.750547, loss_r = 0.038729
# Iteration : 482/1000, loss_c = 1.756667, loss_r = 0.038112
# Iteration : 483/1000, loss_c = 1.764270, loss_r = 0.038031
# Iteration : 484/1000, loss_c = 1.776486, loss_r = 0.037971
# Iteration : 485/1000, loss_c = 1.754561, loss_r = 0.037882
# Iteration : 486/1000, loss_c = 1.744995, loss_r = 0.037524
# Iteration : 487/1000, loss_c = 1.782699, loss_r = 0.037371
# Iteration : 488/1000, loss_c = 1.772400, loss_r = 0.037246
# Iteration : 489/1000, loss_c = 1.749071, loss_r = 0.037193
# Iteration : 490/1000, loss_c = 1.748321, loss_r = 0.037517
# Iteration : 491/1000, loss_c = 1.789078, loss_r = 0.037178
# Iteration : 492/1000, loss_c = 1.756322, loss_r = 0.037309
# Iteration : 493/1000, loss_c = 1.747918, loss_r = 0.036805
# Iteration : 494/1000, loss_c = 1.732064, loss_r = 0.036242
# Iteration : 495/1000, loss_c = 1.727331, loss_r = 0.036058
# Iteration : 496/1000, loss_c = 1.748084, loss_r = 0.036181
# Iteration : 497/1000, loss_c = 1.741110, loss_r = 0.036057
# Iteration : 498/1000, loss_c = 1.764327, loss_r = 0.036040
# Iteration : 499/1000, loss_c = 1.752631, loss_r = 0.036393
# Iteration : 500/1000, loss_c = 1.734685, loss_r = 0.036747
# Iteration : 501/1000, loss_c = 1.758203, loss_r = 0.036348
# Iteration : 502/1000, loss_c = 1.732683, loss_r = 0.036444
# Iteration : 503/1000, loss_c = 1.759858, loss_r = 0.035831
# Iteration : 504/1000, loss_c = 1.756338, loss_r = 0.035212
# Iteration : 505/1000, loss_c = 1.745882, loss_r = 0.035396
# Iteration : 506/1000, loss_c = 1.731556, loss_r = 0.035865
# Iteration : 507/1000, loss_c = 1.713352, loss_r = 0.035210
# Iteration : 508/1000, loss_c = 1.729972, loss_r = 0.034722
# Iteration : 509/1000, loss_c = 1.765156, loss_r = 0.035040
# Iteration : 510/1000, loss_c = 1.752719, loss_r = 0.035586
# Iteration : 511/1000, loss_c = 1.753458, loss_r = 0.035820
# Iteration : 512/1000, loss_c = 1.755187, loss_r = 0.035335
# Iteration : 513/1000, loss_c = 1.723993, loss_r = 0.034383
# Iteration : 514/1000, loss_c = 1.741450, loss_r = 0.034132
# Iteration : 515/1000, loss_c = 1.778389, loss_r = 0.033741
# Iteration : 516/1000, loss_c = 1.740997, loss_r = 0.034220
# Iteration : 517/1000, loss_c = 1.751469, loss_r = 0.034676
# Iteration : 518/1000, loss_c = 1.737947, loss_r = 0.034254
# Iteration : 519/1000, loss_c = 1.730084, loss_r = 0.034161
# Iteration : 520/1000, loss_c = 1.739681, loss_r = 0.033651
# Iteration : 521/1000, loss_c = 1.755552, loss_r = 0.033267
# Iteration : 522/1000, loss_c = 1.723175, loss_r = 0.033144
# Iteration : 523/1000, loss_c = 1.738621, loss_r = 0.033157
# Iteration : 524/1000, loss_c = 1.714964, loss_r = 0.033360
# Iteration : 525/1000, loss_c = 1.737948, loss_r = 0.032676
# Iteration : 526/1000, loss_c = 1.727323, loss_r = 0.032803
# Iteration : 527/1000, loss_c = 1.733268, loss_r = 0.032958
# Iteration : 528/1000, loss_c = 1.731145, loss_r = 0.033082
# Iteration : 529/1000, loss_c = 1.747523, loss_r = 0.033011
# Iteration : 530/1000, loss_c = 1.739884, loss_r = 0.033935
# Iteration : 531/1000, loss_c = 1.714579, loss_r = 0.033401
# Iteration : 532/1000, loss_c = 1.733411, loss_r = 0.032745
# Iteration : 533/1000, loss_c = 1.743936, loss_r = 0.032018
# Iteration : 534/1000, loss_c = 1.760690, loss_r = 0.031950
# Iteration : 535/1000, loss_c = 1.720092, loss_r = 0.031829
# Iteration : 536/1000, loss_c = 1.759431, loss_r = 0.032368
# Iteration : 537/1000, loss_c = 1.728335, loss_r = 0.031687
# Iteration : 538/1000, loss_c = 1.737242, loss_r = 0.031288
# Iteration : 539/1000, loss_c = 1.706401, loss_r = 0.031280
# Iteration : 540/1000, loss_c = 1.746975, loss_r = 0.032510
# Iteration : 541/1000, loss_c = 1.740364, loss_r = 0.032195
# Iteration : 542/1000, loss_c = 1.726213, loss_r = 0.031585
# Iteration : 543/1000, loss_c = 1.714952, loss_r = 0.031372
# Iteration : 544/1000, loss_c = 1.721187, loss_r = 0.031308
# Iteration : 545/1000, loss_c = 1.732132, loss_r = 0.030859
# Iteration : 546/1000, loss_c = 1.750985, loss_r = 0.030120
# Iteration : 547/1000, loss_c = 1.740747, loss_r = 0.029988
# Iteration : 548/1000, loss_c = 1.757652, loss_r = 0.029777
# Iteration : 549/1000, loss_c = 1.718920, loss_r = 0.029919
# Iteration : 550/1000, loss_c = 1.751221, loss_r = 0.030600
# Iteration : 551/1000, loss_c = 1.733518, loss_r = 0.030570
# Iteration : 552/1000, loss_c = 1.723415, loss_r = 0.029960
# Iteration : 553/1000, loss_c = 1.717114, loss_r = 0.029629
# Iteration : 554/1000, loss_c = 1.742953, loss_r = 0.029678
# Iteration : 555/1000, loss_c = 1.715042, loss_r = 0.029814
# Iteration : 556/1000, loss_c = 1.727262, loss_r = 0.029962
# Iteration : 557/1000, loss_c = 1.719252, loss_r = 0.030010
# Iteration : 558/1000, loss_c = 1.734823, loss_r = 0.030113
# Iteration : 559/1000, loss_c = 1.736408, loss_r = 0.029202
# Iteration : 560/1000, loss_c = 1.735336, loss_r = 0.029030
# Iteration : 561/1000, loss_c = 1.710644, loss_r = 0.028676
# Iteration : 562/1000, loss_c = 1.710974, loss_r = 0.028780
# Iteration : 563/1000, loss_c = 1.739018, loss_r = 0.028808
# Iteration : 564/1000, loss_c = 1.737549, loss_r = 0.028646
# Iteration : 565/1000, loss_c = 1.726636, loss_r = 0.028495
# Iteration : 566/1000, loss_c = 1.723705, loss_r = 0.028396
# Iteration : 567/1000, loss_c = 1.718335, loss_r = 0.028202
# Iteration : 568/1000, loss_c = 1.710689, loss_r = 0.028142
# Iteration : 569/1000, loss_c = 1.717107, loss_r = 0.028196
# Iteration : 570/1000, loss_c = 1.740692, loss_r = 0.028123
# Iteration : 571/1000, loss_c = 1.720329, loss_r = 0.028162
# Iteration : 572/1000, loss_c = 1.722319, loss_r = 0.028362
# Iteration : 573/1000, loss_c = 1.751660, loss_r = 0.028295
# Iteration : 574/1000, loss_c = 1.732353, loss_r = 0.027881
# Iteration : 575/1000, loss_c = 1.722198, loss_r = 0.027582
# Iteration : 576/1000, loss_c = 1.717800, loss_r = 0.027733
# Iteration : 577/1000, loss_c = 1.730294, loss_r = 0.027549
# Iteration : 578/1000, loss_c = 1.707254, loss_r = 0.027350
# Iteration : 579/1000, loss_c = 1.756563, loss_r = 0.026994
# Iteration : 580/1000, loss_c = 1.712342, loss_r = 0.027021
# Iteration : 581/1000, loss_c = 1.700470, loss_r = 0.026843
# Iteration : 582/1000, loss_c = 1.704684, loss_r = 0.026757
# Iteration : 583/1000, loss_c = 1.697983, loss_r = 0.026548
# Iteration : 584/1000, loss_c = 1.733852, loss_r = 0.026611
# Iteration : 585/1000, loss_c = 1.707687, loss_r = 0.026646
# Iteration : 586/1000, loss_c = 1.727388, loss_r = 0.026670
# Iteration : 587/1000, loss_c = 1.728700, loss_r = 0.026398
# Iteration : 588/1000, loss_c = 1.728521, loss_r = 0.026168
# Iteration : 589/1000, loss_c = 1.717575, loss_r = 0.025824
# Iteration : 590/1000, loss_c = 1.709511, loss_r = 0.025549
# Iteration : 591/1000, loss_c = 1.684722, loss_r = 0.025431
# Iteration : 592/1000, loss_c = 1.719942, loss_r = 0.025423
# Iteration : 593/1000, loss_c = 1.704698, loss_r = 0.025771
# Iteration : 594/1000, loss_c = 1.703354, loss_r = 0.026144
# Iteration : 595/1000, loss_c = 1.731910, loss_r = 0.025867
# Iteration : 596/1000, loss_c = 1.703382, loss_r = 0.025686
# Iteration : 597/1000, loss_c = 1.702464, loss_r = 0.025795
# Iteration : 598/1000, loss_c = 1.712463, loss_r = 0.025786
# Iteration : 599/1000, loss_c = 1.697382, loss_r = 0.025317
# Iteration : 600/1000, loss_c = 1.714586, loss_r = 0.025511
# Iteration : 601/1000, loss_c = 1.744699, loss_r = 0.025334
# Iteration : 602/1000, loss_c = 1.741174, loss_r = 0.025256
# Iteration : 603/1000, loss_c = 1.727691, loss_r = 0.025316
# Iteration : 604/1000, loss_c = 1.686822, loss_r = 0.024988
# Iteration : 605/1000, loss_c = 1.718018, loss_r = 0.024527
# Iteration : 606/1000, loss_c = 1.717569, loss_r = 0.024282
# Iteration : 607/1000, loss_c = 1.719564, loss_r = 0.024148
# Iteration : 608/1000, loss_c = 1.697300, loss_r = 0.024192
# Iteration : 609/1000, loss_c = 1.703376, loss_r = 0.023852
# Iteration : 610/1000, loss_c = 1.732087, loss_r = 0.023776
# Iteration : 611/1000, loss_c = 1.689068, loss_r = 0.023698
# Iteration : 612/1000, loss_c = 1.699869, loss_r = 0.023515
# Iteration : 613/1000, loss_c = 1.708555, loss_r = 0.023555
# Iteration : 614/1000, loss_c = 1.686602, loss_r = 0.023720
# Iteration : 615/1000, loss_c = 1.715950, loss_r = 0.024372
# Iteration : 616/1000, loss_c = 1.698593, loss_r = 0.024427
# Iteration : 617/1000, loss_c = 1.698508, loss_r = 0.024208
# Iteration : 618/1000, loss_c = 1.697543, loss_r = 0.023819
# Iteration : 619/1000, loss_c = 1.686315, loss_r = 0.023704
# Iteration : 620/1000, loss_c = 1.689306, loss_r = 0.023441
# Iteration : 621/1000, loss_c = 1.707925, loss_r = 0.023598
# Iteration : 622/1000, loss_c = 1.702640, loss_r = 0.023429
# Iteration : 623/1000, loss_c = 1.687168, loss_r = 0.023249
# Iteration : 624/1000, loss_c = 1.718751, loss_r = 0.023156
# Iteration : 625/1000, loss_c = 1.696780, loss_r = 0.023241
# Iteration : 626/1000, loss_c = 1.720023, loss_r = 0.023350
# Iteration : 627/1000, loss_c = 1.711540, loss_r = 0.023129
# Iteration : 628/1000, loss_c = 1.688801, loss_r = 0.022717
# Iteration : 629/1000, loss_c = 1.686142, loss_r = 0.022680
# Iteration : 630/1000, loss_c = 1.710039, loss_r = 0.022659
# Iteration : 631/1000, loss_c = 1.703464, loss_r = 0.023035
# Iteration : 632/1000, loss_c = 1.692717, loss_r = 0.023156
# Iteration : 633/1000, loss_c = 1.702723, loss_r = 0.022829
# Iteration : 634/1000, loss_c = 1.701222, loss_r = 0.022387
# Iteration : 635/1000, loss_c = 1.674934, loss_r = 0.021851
# Iteration : 636/1000, loss_c = 1.708799, loss_r = 0.021694
# Iteration : 637/1000, loss_c = 1.677312, loss_r = 0.021888
# Iteration : 638/1000, loss_c = 1.697056, loss_r = 0.022105
# Iteration : 639/1000, loss_c = 1.689622, loss_r = 0.022593
# Iteration : 640/1000, loss_c = 1.699549, loss_r = 0.022434
# Iteration : 641/1000, loss_c = 1.702838, loss_r = 0.021922
# Iteration : 642/1000, loss_c = 1.693019, loss_r = 0.021830
# Iteration : 643/1000, loss_c = 1.690510, loss_r = 0.021707
# Iteration : 644/1000, loss_c = 1.704189, loss_r = 0.021251
# Iteration : 645/1000, loss_c = 1.694293, loss_r = 0.021168
# Iteration : 646/1000, loss_c = 1.701338, loss_r = 0.021187
# Iteration : 647/1000, loss_c = 1.716048, loss_r = 0.021226
# Iteration : 648/1000, loss_c = 1.719542, loss_r = 0.021144
# Iteration : 649/1000, loss_c = 1.709055, loss_r = 0.021145
# Iteration : 650/1000, loss_c = 1.699975, loss_r = 0.021236
# Iteration : 651/1000, loss_c = 1.693450, loss_r = 0.021235
# Iteration : 652/1000, loss_c = 1.684479, loss_r = 0.021105
# Iteration : 653/1000, loss_c = 1.705816, loss_r = 0.020949
# Iteration : 654/1000, loss_c = 1.697684, loss_r = 0.020785
# Iteration : 655/1000, loss_c = 1.706773, loss_r = 0.020671
# Iteration : 656/1000, loss_c = 1.723471, loss_r = 0.020641
# Iteration : 657/1000, loss_c = 1.685661, loss_r = 0.020549
# Iteration : 658/1000, loss_c = 1.687113, loss_r = 0.020548
# Iteration : 659/1000, loss_c = 1.681159, loss_r = 0.020451
# Iteration : 660/1000, loss_c = 1.713584, loss_r = 0.020328
# Iteration : 661/1000, loss_c = 1.695308, loss_r = 0.020226
# Iteration : 662/1000, loss_c = 1.696001, loss_r = 0.020262
# Iteration : 663/1000, loss_c = 1.703015, loss_r = 0.020128
# Iteration : 664/1000, loss_c = 1.669447, loss_r = 0.019953
# Iteration : 665/1000, loss_c = 1.677468, loss_r = 0.020100
# Iteration : 666/1000, loss_c = 1.675107, loss_r = 0.019922
# Iteration : 667/1000, loss_c = 1.702255, loss_r = 0.020054
# Iteration : 668/1000, loss_c = 1.666687, loss_r = 0.019790
# Iteration : 669/1000, loss_c = 1.697600, loss_r = 0.019729
# Iteration : 670/1000, loss_c = 1.685556, loss_r = 0.019601
# Iteration : 671/1000, loss_c = 1.656134, loss_r = 0.019439
# Iteration : 672/1000, loss_c = 1.680593, loss_r = 0.019312
# Iteration : 673/1000, loss_c = 1.679618, loss_r = 0.019397
# Iteration : 674/1000, loss_c = 1.678597, loss_r = 0.019648
# Iteration : 675/1000, loss_c = 1.665700, loss_r = 0.019431
# Iteration : 676/1000, loss_c = 1.715715, loss_r = 0.019159
# Iteration : 677/1000, loss_c = 1.694973, loss_r = 0.018926
# Iteration : 678/1000, loss_c = 1.643629, loss_r = 0.019012
# Iteration : 679/1000, loss_c = 1.698867, loss_r = 0.019006
# Iteration : 680/1000, loss_c = 1.690736, loss_r = 0.019111
# Iteration : 681/1000, loss_c = 1.676335, loss_r = 0.018892
# Iteration : 682/1000, loss_c = 1.683220, loss_r = 0.018985
# Iteration : 683/1000, loss_c = 1.689022, loss_r = 0.018866
# Iteration : 684/1000, loss_c = 1.692720, loss_r = 0.018918
# Iteration : 685/1000, loss_c = 1.668673, loss_r = 0.018596
# Iteration : 686/1000, loss_c = 1.667626, loss_r = 0.018420
# Iteration : 687/1000, loss_c = 1.706675, loss_r = 0.018403
# Iteration : 688/1000, loss_c = 1.689162, loss_r = 0.018520
# Iteration : 689/1000, loss_c = 1.696530, loss_r = 0.018278
# Iteration : 690/1000, loss_c = 1.686599, loss_r = 0.018360
# Iteration : 691/1000, loss_c = 1.692550, loss_r = 0.018149
# Iteration : 692/1000, loss_c = 1.646767, loss_r = 0.018155
# Iteration : 693/1000, loss_c = 1.701515, loss_r = 0.018127
# Iteration : 694/1000, loss_c = 1.663979, loss_r = 0.018033
# Iteration : 695/1000, loss_c = 1.692199, loss_r = 0.018049
# Iteration : 696/1000, loss_c = 1.690233, loss_r = 0.017886
# Iteration : 697/1000, loss_c = 1.688792, loss_r = 0.017890
# Iteration : 698/1000, loss_c = 1.682122, loss_r = 0.017811
# Iteration : 699/1000, loss_c = 1.698785, loss_r = 0.017873
# Iteration : 700/1000, loss_c = 1.684487, loss_r = 0.017779
# Iteration : 701/1000, loss_c = 1.667536, loss_r = 0.017879
# Iteration : 702/1000, loss_c = 1.676646, loss_r = 0.017935
# Iteration : 703/1000, loss_c = 1.686369, loss_r = 0.017826
# Iteration : 704/1000, loss_c = 1.678759, loss_r = 0.017859
# Iteration : 705/1000, loss_c = 1.680243, loss_r = 0.018055
# Iteration : 706/1000, loss_c = 1.679219, loss_r = 0.017647
# Iteration : 707/1000, loss_c = 1.672509, loss_r = 0.017670
# Iteration : 708/1000, loss_c = 1.709583, loss_r = 0.017655
# Iteration : 709/1000, loss_c = 1.667103, loss_r = 0.017426
# Iteration : 710/1000, loss_c = 1.697476, loss_r = 0.017245
# Iteration : 711/1000, loss_c = 1.691316, loss_r = 0.017245
# Iteration : 712/1000, loss_c = 1.676301, loss_r = 0.017408
# Iteration : 713/1000, loss_c = 1.666368, loss_r = 0.017332
# Iteration : 714/1000, loss_c = 1.682676, loss_r = 0.017240
# Iteration : 715/1000, loss_c = 1.682015, loss_r = 0.017127
# Iteration : 716/1000, loss_c = 1.653468, loss_r = 0.017098
# Iteration : 717/1000, loss_c = 1.662827, loss_r = 0.017090
# Iteration : 718/1000, loss_c = 1.680875, loss_r = 0.016899
# Iteration : 719/1000, loss_c = 1.683728, loss_r = 0.016845
# Iteration : 720/1000, loss_c = 1.700250, loss_r = 0.016890
# Iteration : 721/1000, loss_c = 1.673802, loss_r = 0.017101
# Iteration : 722/1000, loss_c = 1.690071, loss_r = 0.017040
# Iteration : 723/1000, loss_c = 1.666397, loss_r = 0.016885
# Iteration : 724/1000, loss_c = 1.647201, loss_r = 0.016781
# Iteration : 725/1000, loss_c = 1.689096, loss_r = 0.016769
# Iteration : 726/1000, loss_c = 1.668354, loss_r = 0.016596
# Iteration : 727/1000, loss_c = 1.658149, loss_r = 0.016483
# Iteration : 728/1000, loss_c = 1.682981, loss_r = 0.016491
# Iteration : 729/1000, loss_c = 1.682696, loss_r = 0.016452
# Iteration : 730/1000, loss_c = 1.675909, loss_r = 0.016267
# Iteration : 731/1000, loss_c = 1.682569, loss_r = 0.016300
# Iteration : 732/1000, loss_c = 1.660410, loss_r = 0.016216
# Iteration : 733/1000, loss_c = 1.673005, loss_r = 0.016283
# Iteration : 734/1000, loss_c = 1.682085, loss_r = 0.016175
# Iteration : 735/1000, loss_c = 1.671296, loss_r = 0.016082
# Iteration : 736/1000, loss_c = 1.642925, loss_r = 0.016108
# Iteration : 737/1000, loss_c = 1.655108, loss_r = 0.016129
# Iteration : 738/1000, loss_c = 1.681293, loss_r = 0.016085
# Iteration : 739/1000, loss_c = 1.657608, loss_r = 0.015991
# Iteration : 740/1000, loss_c = 1.665243, loss_r = 0.015918
# Iteration : 741/1000, loss_c = 1.663263, loss_r = 0.015874
# Iteration : 742/1000, loss_c = 1.672228, loss_r = 0.015822
# Iteration : 743/1000, loss_c = 1.679783, loss_r = 0.015731
# Iteration : 744/1000, loss_c = 1.687437, loss_r = 0.015732
# Iteration : 745/1000, loss_c = 1.651016, loss_r = 0.015608
# Iteration : 746/1000, loss_c = 1.671225, loss_r = 0.015608
# Iteration : 747/1000, loss_c = 1.664927, loss_r = 0.015643
# Iteration : 748/1000, loss_c = 1.686893, loss_r = 0.015618
# Iteration : 749/1000, loss_c = 1.669185, loss_r = 0.015612
# Iteration : 750/1000, loss_c = 1.675312, loss_r = 0.015547
# Iteration : 751/1000, loss_c = 1.670656, loss_r = 0.015439
# Iteration : 752/1000, loss_c = 1.696126, loss_r = 0.015422
# Iteration : 753/1000, loss_c = 1.663475, loss_r = 0.015471
# Iteration : 754/1000, loss_c = 1.675283, loss_r = 0.015386
# Iteration : 755/1000, loss_c = 1.663012, loss_r = 0.015381
# Iteration : 756/1000, loss_c = 1.694596, loss_r = 0.015402
# Iteration : 757/1000, loss_c = 1.676129, loss_r = 0.015312
# Iteration : 758/1000, loss_c = 1.673775, loss_r = 0.015255
# Iteration : 759/1000, loss_c = 1.674244, loss_r = 0.015272
# Iteration : 760/1000, loss_c = 1.679475, loss_r = 0.015152
# Iteration : 761/1000, loss_c = 1.683641, loss_r = 0.015132
# Iteration : 762/1000, loss_c = 1.691188, loss_r = 0.015097
# Iteration : 763/1000, loss_c = 1.691111, loss_r = 0.015043
# Iteration : 764/1000, loss_c = 1.661301, loss_r = 0.015063
# Iteration : 765/1000, loss_c = 1.688367, loss_r = 0.015067
# Iteration : 766/1000, loss_c = 1.656298, loss_r = 0.015051
# Iteration : 767/1000, loss_c = 1.668472, loss_r = 0.015080
# Iteration : 768/1000, loss_c = 1.657772, loss_r = 0.015073
# Iteration : 769/1000, loss_c = 1.678427, loss_r = 0.015068
# Iteration : 770/1000, loss_c = 1.639762, loss_r = 0.014947
# Iteration : 771/1000, loss_c = 1.640354, loss_r = 0.014838
# Iteration : 772/1000, loss_c = 1.656742, loss_r = 0.014842
# Iteration : 773/1000, loss_c = 1.666471, loss_r = 0.014789
# Iteration : 774/1000, loss_c = 1.645232, loss_r = 0.014655
# Iteration : 775/1000, loss_c = 1.642145, loss_r = 0.014619
# Iteration : 776/1000, loss_c = 1.658980, loss_r = 0.014586
# Iteration : 777/1000, loss_c = 1.645298, loss_r = 0.014620
# Iteration : 778/1000, loss_c = 1.668262, loss_r = 0.014644
# Iteration : 779/1000, loss_c = 1.661056, loss_r = 0.014525
# Iteration : 780/1000, loss_c = 1.661091, loss_r = 0.014483
# Iteration : 781/1000, loss_c = 1.662598, loss_r = 0.014447
# Iteration : 782/1000, loss_c = 1.691901, loss_r = 0.014440
# Iteration : 783/1000, loss_c = 1.671977, loss_r = 0.014417
# Iteration : 784/1000, loss_c = 1.663625, loss_r = 0.014339
# Iteration : 785/1000, loss_c = 1.636920, loss_r = 0.014342
# Iteration : 786/1000, loss_c = 1.685190, loss_r = 0.014289
# Iteration : 787/1000, loss_c = 1.663820, loss_r = 0.014337
# Iteration : 788/1000, loss_c = 1.691813, loss_r = 0.014321
# Iteration : 789/1000, loss_c = 1.675353, loss_r = 0.014287
# Iteration : 790/1000, loss_c = 1.637540, loss_r = 0.014257
# Iteration : 791/1000, loss_c = 1.683034, loss_r = 0.014321
# Iteration : 792/1000, loss_c = 1.650197, loss_r = 0.014268
# Iteration : 793/1000, loss_c = 1.683122, loss_r = 0.014212
# Iteration : 794/1000, loss_c = 1.673168, loss_r = 0.014112
# Iteration : 795/1000, loss_c = 1.665549, loss_r = 0.014093
# Iteration : 796/1000, loss_c = 1.663710, loss_r = 0.014012
# Iteration : 797/1000, loss_c = 1.657132, loss_r = 0.013939
# Iteration : 798/1000, loss_c = 1.651149, loss_r = 0.013912
# Iteration : 799/1000, loss_c = 1.659165, loss_r = 0.013941
# Iteration : 800/1000, loss_c = 1.658920, loss_r = 0.013884
# Iteration : 801/1000, loss_c = 1.665354, loss_r = 0.013869
# Iteration : 802/1000, loss_c = 1.642833, loss_r = 0.013887
# Iteration : 803/1000, loss_c = 1.631417, loss_r = 0.013892
# Iteration : 804/1000, loss_c = 1.665829, loss_r = 0.013846
# Iteration : 805/1000, loss_c = 1.656936, loss_r = 0.013782
# Iteration : 806/1000, loss_c = 1.676779, loss_r = 0.013780
# Iteration : 807/1000, loss_c = 1.654630, loss_r = 0.013786
# Iteration : 808/1000, loss_c = 1.671972, loss_r = 0.013692
# Iteration : 809/1000, loss_c = 1.663648, loss_r = 0.013652
# Iteration : 810/1000, loss_c = 1.661383, loss_r = 0.013662
# Iteration : 811/1000, loss_c = 1.641979, loss_r = 0.013627
# Iteration : 812/1000, loss_c = 1.640600, loss_r = 0.013584
# Iteration : 813/1000, loss_c = 1.630626, loss_r = 0.013577
# Iteration : 814/1000, loss_c = 1.656717, loss_r = 0.013580
# Iteration : 815/1000, loss_c = 1.626770, loss_r = 0.013543
# Iteration : 816/1000, loss_c = 1.700881, loss_r = 0.013517
# Iteration : 817/1000, loss_c = 1.682755, loss_r = 0.013511
# Iteration : 818/1000, loss_c = 1.663293, loss_r = 0.013514
# Iteration : 819/1000, loss_c = 1.659320, loss_r = 0.013510
# Iteration : 820/1000, loss_c = 1.651301, loss_r = 0.013472
# Iteration : 821/1000, loss_c = 1.661583, loss_r = 0.013435
# Iteration : 822/1000, loss_c = 1.636601, loss_r = 0.013459
# Iteration : 823/1000, loss_c = 1.668508, loss_r = 0.013395
# Iteration : 824/1000, loss_c = 1.671613, loss_r = 0.013335
# Iteration : 825/1000, loss_c = 1.646912, loss_r = 0.013327
# Iteration : 826/1000, loss_c = 1.623153, loss_r = 0.013318
# Iteration : 827/1000, loss_c = 1.655395, loss_r = 0.013329
# Iteration : 828/1000, loss_c = 1.662269, loss_r = 0.013260
# Iteration : 829/1000, loss_c = 1.649718, loss_r = 0.013274
# Iteration : 830/1000, loss_c = 1.646334, loss_r = 0.013240
# Iteration : 831/1000, loss_c = 1.634797, loss_r = 0.013248
# Iteration : 832/1000, loss_c = 1.644251, loss_r = 0.013249
# Iteration : 833/1000, loss_c = 1.643841, loss_r = 0.013198
# Iteration : 834/1000, loss_c = 1.666245, loss_r = 0.013153
# Iteration : 835/1000, loss_c = 1.656572, loss_r = 0.013178
# Iteration : 836/1000, loss_c = 1.657406, loss_r = 0.013148
# Iteration : 837/1000, loss_c = 1.653597, loss_r = 0.013117
# Iteration : 838/1000, loss_c = 1.651996, loss_r = 0.013107
# Iteration : 839/1000, loss_c = 1.640059, loss_r = 0.013042
# Iteration : 840/1000, loss_c = 1.661592, loss_r = 0.013055
# Iteration : 841/1000, loss_c = 1.673251, loss_r = 0.013012
# Iteration : 842/1000, loss_c = 1.656343, loss_r = 0.013010
# Iteration : 843/1000, loss_c = 1.666209, loss_r = 0.013003
# Iteration : 844/1000, loss_c = 1.647450, loss_r = 0.013008
# Iteration : 845/1000, loss_c = 1.646680, loss_r = 0.012989
# Iteration : 846/1000, loss_c = 1.653439, loss_r = 0.012992
# Iteration : 847/1000, loss_c = 1.657114, loss_r = 0.012966
# Iteration : 848/1000, loss_c = 1.652001, loss_r = 0.012947
# Iteration : 849/1000, loss_c = 1.662718, loss_r = 0.012935
# Iteration : 850/1000, loss_c = 1.674921, loss_r = 0.012914
# Iteration : 851/1000, loss_c = 1.663348, loss_r = 0.012881
# Iteration : 852/1000, loss_c = 1.660551, loss_r = 0.012845
# Iteration : 853/1000, loss_c = 1.663273, loss_r = 0.012820
# Iteration : 854/1000, loss_c = 1.659796, loss_r = 0.012818
# Iteration : 855/1000, loss_c = 1.638362, loss_r = 0.012780
# Iteration : 856/1000, loss_c = 1.667800, loss_r = 0.012784
# Iteration : 857/1000, loss_c = 1.657009, loss_r = 0.012804
# Iteration : 858/1000, loss_c = 1.659178, loss_r = 0.012800
# Iteration : 859/1000, loss_c = 1.643124, loss_r = 0.012804
# Iteration : 860/1000, loss_c = 1.658864, loss_r = 0.012736
# Iteration : 861/1000, loss_c = 1.664024, loss_r = 0.012736
# Iteration : 862/1000, loss_c = 1.635385, loss_r = 0.012710
# Iteration : 863/1000, loss_c = 1.636375, loss_r = 0.012716
# Iteration : 864/1000, loss_c = 1.656907, loss_r = 0.012665
# Iteration : 865/1000, loss_c = 1.659352, loss_r = 0.012667
# Iteration : 866/1000, loss_c = 1.662280, loss_r = 0.012626
# Iteration : 867/1000, loss_c = 1.637108, loss_r = 0.012623
# Iteration : 868/1000, loss_c = 1.646812, loss_r = 0.012611
# Iteration : 869/1000, loss_c = 1.668109, loss_r = 0.012605
# Iteration : 870/1000, loss_c = 1.654803, loss_r = 0.012595
# Iteration : 871/1000, loss_c = 1.660663, loss_r = 0.012603
# Iteration : 872/1000, loss_c = 1.647769, loss_r = 0.012552
# Iteration : 873/1000, loss_c = 1.668086, loss_r = 0.012531
# Iteration : 874/1000, loss_c = 1.648142, loss_r = 0.012538
# Iteration : 875/1000, loss_c = 1.666510, loss_r = 0.012544
# Iteration : 876/1000, loss_c = 1.678861, loss_r = 0.012550
# Iteration : 877/1000, loss_c = 1.651965, loss_r = 0.012507
# Iteration : 878/1000, loss_c = 1.632703, loss_r = 0.012533
# Iteration : 879/1000, loss_c = 1.657392, loss_r = 0.012491
# Iteration : 880/1000, loss_c = 1.648520, loss_r = 0.012483
# Iteration : 881/1000, loss_c = 1.656168, loss_r = 0.012463
# Iteration : 882/1000, loss_c = 1.670477, loss_r = 0.012445
# Iteration : 883/1000, loss_c = 1.623013, loss_r = 0.012420
# Iteration : 884/1000, loss_c = 1.642573, loss_r = 0.012429
# Iteration : 885/1000, loss_c = 1.652533, loss_r = 0.012415
# Iteration : 886/1000, loss_c = 1.667302, loss_r = 0.012380
# Iteration : 887/1000, loss_c = 1.653857, loss_r = 0.012368
# Iteration : 888/1000, loss_c = 1.655153, loss_r = 0.012364
# Iteration : 889/1000, loss_c = 1.647735, loss_r = 0.012366
# Iteration : 890/1000, loss_c = 1.650005, loss_r = 0.012373
# Iteration : 891/1000, loss_c = 1.652837, loss_r = 0.012356
# Iteration : 892/1000, loss_c = 1.655823, loss_r = 0.012353
# Iteration : 893/1000, loss_c = 1.661478, loss_r = 0.012317
# Iteration : 894/1000, loss_c = 1.640206, loss_r = 0.012302
# Iteration : 895/1000, loss_c = 1.644250, loss_r = 0.012291
# Iteration : 896/1000, loss_c = 1.645443, loss_r = 0.012285
# Iteration : 897/1000, loss_c = 1.645268, loss_r = 0.012283
# Iteration : 898/1000, loss_c = 1.647675, loss_r = 0.012290
# Iteration : 899/1000, loss_c = 1.657361, loss_r = 0.012277
# Iteration : 900/1000, loss_c = 1.648028, loss_r = 0.012257
# Iteration : 901/1000, loss_c = 1.642259, loss_r = 0.012239
# Iteration : 902/1000, loss_c = 1.648920, loss_r = 0.012238
# Iteration : 903/1000, loss_c = 1.638946, loss_r = 0.012243
# Iteration : 904/1000, loss_c = 1.643277, loss_r = 0.012223
# Iteration : 905/1000, loss_c = 1.646362, loss_r = 0.012198
# Iteration : 906/1000, loss_c = 1.654112, loss_r = 0.012198
# Iteration : 907/1000, loss_c = 1.658119, loss_r = 0.012189
# Iteration : 908/1000, loss_c = 1.664360, loss_r = 0.012174
# Iteration : 909/1000, loss_c = 1.618913, loss_r = 0.012147
# Iteration : 910/1000, loss_c = 1.659626, loss_r = 0.012139
# Iteration : 911/1000, loss_c = 1.634460, loss_r = 0.012153
# Iteration : 912/1000, loss_c = 1.653387, loss_r = 0.012135
# Iteration : 913/1000, loss_c = 1.651324, loss_r = 0.012132
# Iteration : 914/1000, loss_c = 1.631770, loss_r = 0.012123
# Iteration : 915/1000, loss_c = 1.660681, loss_r = 0.012111
# Iteration : 916/1000, loss_c = 1.638777, loss_r = 0.012099
# Iteration : 917/1000, loss_c = 1.654246, loss_r = 0.012127
# Iteration : 918/1000, loss_c = 1.648907, loss_r = 0.012097
# Iteration : 919/1000, loss_c = 1.642444, loss_r = 0.012102
# Iteration : 920/1000, loss_c = 1.636373, loss_r = 0.012075
# Iteration : 921/1000, loss_c = 1.622651, loss_r = 0.012073
# Iteration : 922/1000, loss_c = 1.652747, loss_r = 0.012079
# Iteration : 923/1000, loss_c = 1.632449, loss_r = 0.012055
# Iteration : 924/1000, loss_c = 1.638987, loss_r = 0.012042
# Iteration : 925/1000, loss_c = 1.655815, loss_r = 0.012041
# Iteration : 926/1000, loss_c = 1.652934, loss_r = 0.012032
# Iteration : 927/1000, loss_c = 1.639973, loss_r = 0.012032
# Iteration : 928/1000, loss_c = 1.656356, loss_r = 0.012015
# Iteration : 929/1000, loss_c = 1.653843, loss_r = 0.012016
# Iteration : 930/1000, loss_c = 1.630411, loss_r = 0.012007
# Iteration : 931/1000, loss_c = 1.654006, loss_r = 0.012001
# Iteration : 932/1000, loss_c = 1.645649, loss_r = 0.011993
# Iteration : 933/1000, loss_c = 1.638663, loss_r = 0.011988
# Iteration : 934/1000, loss_c = 1.653353, loss_r = 0.011977
# Iteration : 935/1000, loss_c = 1.653372, loss_r = 0.011970
# Iteration : 936/1000, loss_c = 1.640984, loss_r = 0.011981
# Iteration : 937/1000, loss_c = 1.639865, loss_r = 0.011976
# Iteration : 938/1000, loss_c = 1.646036, loss_r = 0.011959
# Iteration : 939/1000, loss_c = 1.671079, loss_r = 0.011967
# Iteration : 940/1000, loss_c = 1.632839, loss_r = 0.011951
# Iteration : 941/1000, loss_c = 1.635238, loss_r = 0.011941
# Iteration : 942/1000, loss_c = 1.673686, loss_r = 0.011936
# Iteration : 943/1000, loss_c = 1.639442, loss_r = 0.011943
# Iteration : 944/1000, loss_c = 1.639229, loss_r = 0.011934
# Iteration : 945/1000, loss_c = 1.661534, loss_r = 0.011923
# Iteration : 946/1000, loss_c = 1.626337, loss_r = 0.011918
# Iteration : 947/1000, loss_c = 1.651224, loss_r = 0.011918
# Iteration : 948/1000, loss_c = 1.657210, loss_r = 0.011900
# Iteration : 949/1000, loss_c = 1.648743, loss_r = 0.011902
# Iteration : 950/1000, loss_c = 1.636223, loss_r = 0.011902
# Iteration : 951/1000, loss_c = 1.639697, loss_r = 0.011886
# Iteration : 952/1000, loss_c = 1.653345, loss_r = 0.011891
# Iteration : 953/1000, loss_c = 1.663624, loss_r = 0.011886
# Iteration : 954/1000, loss_c = 1.656302, loss_r = 0.011882
# Iteration : 955/1000, loss_c = 1.664210, loss_r = 0.011883
# Iteration : 956/1000, loss_c = 1.643218, loss_r = 0.011881
# Iteration : 957/1000, loss_c = 1.641379, loss_r = 0.011868
# Iteration : 958/1000, loss_c = 1.662604, loss_r = 0.011862
# Iteration : 959/1000, loss_c = 1.645258, loss_r = 0.011859
# Iteration : 960/1000, loss_c = 1.646242, loss_r = 0.011852
# Iteration : 961/1000, loss_c = 1.659427, loss_r = 0.011850
# Iteration : 962/1000, loss_c = 1.654991, loss_r = 0.011851
# Iteration : 963/1000, loss_c = 1.669672, loss_r = 0.011847
# Iteration : 964/1000, loss_c = 1.651945, loss_r = 0.011843
# Iteration : 965/1000, loss_c = 1.649700, loss_r = 0.011838
# Iteration : 966/1000, loss_c = 1.668694, loss_r = 0.011828
# Iteration : 967/1000, loss_c = 1.646333, loss_r = 0.011824
# Iteration : 968/1000, loss_c = 1.640465, loss_r = 0.011822
# Iteration : 969/1000, loss_c = 1.654547, loss_r = 0.011811
# Iteration : 970/1000, loss_c = 1.642527, loss_r = 0.011810
# Iteration : 971/1000, loss_c = 1.659594, loss_r = 0.011815
# Iteration : 972/1000, loss_c = 1.656581, loss_r = 0.011805
# Iteration : 973/1000, loss_c = 1.646981, loss_r = 0.011810
# Iteration : 974/1000, loss_c = 1.663575, loss_r = 0.011811
# Iteration : 975/1000, loss_c = 1.648449, loss_r = 0.011799
# Iteration : 976/1000, loss_c = 1.656237, loss_r = 0.011800
# Iteration : 977/1000, loss_c = 1.625302, loss_r = 0.011793
# Iteration : 978/1000, loss_c = 1.669485, loss_r = 0.011798
# Iteration : 979/1000, loss_c = 1.650127, loss_r = 0.011791
# Iteration : 980/1000, loss_c = 1.642323, loss_r = 0.011784
# Iteration : 981/1000, loss_c = 1.658230, loss_r = 0.011783
# Iteration : 982/1000, loss_c = 1.621183, loss_r = 0.011778
# Iteration : 983/1000, loss_c = 1.647476, loss_r = 0.011774
# Iteration : 984/1000, loss_c = 1.661736, loss_r = 0.011770
# Iteration : 985/1000, loss_c = 1.644386, loss_r = 0.011769
# Iteration : 986/1000, loss_c = 1.637591, loss_r = 0.011767
# Iteration : 987/1000, loss_c = 1.642700, loss_r = 0.011773
# Iteration : 988/1000, loss_c = 1.668551, loss_r = 0.011768
# Iteration : 989/1000, loss_c = 1.626164, loss_r = 0.011762
# Iteration : 990/1000, loss_c = 1.643779, loss_r = 0.011761
# Iteration : 991/1000, loss_c = 1.638721, loss_r = 0.011754
# Iteration : 992/1000, loss_c = 1.654081, loss_r = 0.011751
# Iteration : 993/1000, loss_c = 1.645011, loss_r = 0.011747
# Iteration : 994/1000, loss_c = 1.657939, loss_r = 0.011749
# Iteration : 995/1000, loss_c = 1.641916, loss_r = 0.011748
# Iteration : 996/1000, loss_c = 1.634728, loss_r = 0.011737
# Iteration : 997/1000, loss_c = 1.668412, loss_r = 0.011740
# Iteration : 998/1000, loss_c = 1.659980, loss_r = 0.011737
# Iteration : 999/1000, loss_c = 1.641675, loss_r = 0.011739
# Iteration : 1000/1000, loss_c = 1.651829, loss_r = 0.011734

# %%
model.load_state_dict(torch.load(save_path)['net'])
# optimizer.load_state_dict(torch.load(save_path)['opti'])
torch.load(save_path)['loss_r']
# Out:
# 0.011734420841094106

# %%
correct=0
total = 0
model.eval()
with torch.no_grad():
    for (inputs, labels) in test_loader:
        code = torch.zeros(inputs.size(0), 10, device=device)
        inputs = inputs.to(device)
        labels = labels.to(device)
        output = model(inputs)
        ypred = output.max(dim=1, keepdim=True)[1].squeeze(1)
        correct += ypred.eq(labels).sum()
        total += ypred.size(0)
print("Acc", correct/total)
# Out:
# Acc tensor(0.6426, device='cuda:0')

# %%
model.eval()
error_list = []
recon_list = []
org_list = []
label_list = []

with torch.no_grad():
    for codes, labels, imgs in train_loader_mem:
        imgs = imgs.to(device)
        imgrecon = model.forward_transposed(codes)
        error = ((imgs - imgrecon)**2).sum(dim=(1,2,3))/(3*32*32)
        error_list.append(error.cpu().numpy())
        recon_list.append(imgrecon.cpu())
        org_list.append(imgs.cpu())
        label_list.append(labels.cpu().numpy())
error_list = np.concatenate(error_list)
recon_list = torch.cat(recon_list, axis=0)
org_list = torch.cat(org_list, axis=0)
label_list = np.concatenate(label_list)

# %%
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms.v2.functional as Func

plt.rcParams["savefig.bbox"] = "tight"

def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = Func.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
with torch.no_grad():
    for codes, labels, imgs in train_loader_mem:
        for img in imgs[:10]:
            show(img)
        imgs = imgs.to(device)
        imgrecons = model.forward_transposed(codes)
        for imgrecon in imgrecons[:10]:
            show(imgrecon)
        break
